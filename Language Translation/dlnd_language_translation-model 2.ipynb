# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    
    source_text_sentences = [sentence for sentence in source_text.split('\n')]
    
    target_text_sentences = [sentence + ' <EOS>' for sentence in target_text.split('\n')]
    
    source_sentences_id = [[source_vocab_to_int[word] for word in sentence.split()] for sentence in source_text_sentences]
    
    target_sentences_id = [[target_vocab_to_int[word] for word in sentence.split()] for sentence in target_text_sentences]
    
    return (source_sentences_id, target_sentences_id)
    
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    inputs = tf.placeholder(tf.int32, shape=(None, None), name='input')
    targets = tf.placeholder(tf.int32, shape=(None, None))
    learning_rate = tf.placeholder(tf.float32)
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    target_seq_lenth = tf.placeholder(tf.int32, shape=[None], name= "target_sequence_length")
    max_target_len = tf.reduce_max(target_seq_lenth, name= 'max_target_len')
    source_seq_length = tf.placeholder(tf.int32, shape=[None], name= "source_sequence_length")
    
    return (inputs, targets, learning_rate, keep_prob, target_seq_lenth, max_target_len, source_seq_length)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    last_batch_id = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    result = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), last_batch_id], 1)
    return result

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    # Got help from udacity discussion forum
    # (https://discussions.udacity.com/t/help-me-for-the-encoding-layer-implementation/377704)
    
    
    n_stacked_layer = 2
    
    embed_input = tf.contrib.layers.embed_sequence(rnn_inputs, source_vocab_size, encoding_embedding_size)
    
    
    def make_cell(rnn_size):
        
        cell = tf.contrib.rnn.LSTMCell(rnn_size, initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
    
        drop = tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=keep_prob)
        return drop
    
    stacked_layer = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
    
    output, state = tf.nn.dynamic_rnn(cell=stacked_layer, inputs=embed_input, sequence_length=source_sequence_length, dtype=tf.float32)
    
    return output, state
    
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    helper = tf.contrib.seq2seq.TrainingHelper(dec_embed_input, target_sequence_length)
    decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, helper, encoder_state, output_layer)
    f_output, _= tf.contrib.seq2seq.dynamic_decode(decoder,maximum_iterations=max_summary_length)
    return f_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    # got help from an online github repository and udacity discussion board
    
    start_ids = tf.tile([start_of_sequence_id], [batch_size])
    
    embedding_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings, start_ids, end_of_sequence_id)
    
    basic_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, embedding_helper, encoder_state, output_layer)
    
    f_output, _= tf.contrib.seq2seq.dynamic_decode(basic_decoder,maximum_iterations=max_target_sequence_length)
    
    return f_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    def build_cell(rnn_size, keep_prob):
        lstm = tf.contrib.rnn.LSTMCell(rnn_size)
        lstm_drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
        return lstm_drop
    
    stacking_lstm = tf.contrib.rnn.MultiRNNCell([build_cell(rnn_size, keep_prob) for _ in range(num_layers)])
    
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)

    dense_layer = Dense(target_vocab_size,kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))
    
    with tf.variable_scope("decode") as scope:
        train_decoder_output = decoding_layer_train(
            encoder_state, stacking_lstm, dec_embed_input, 
            target_sequence_length, max_target_sequence_length, 
            dense_layer, keep_prob)
        
        scope.reuse_variables()
        
        inference_decoder_output = decoding_layer_infer(
            encoder_state, stacking_lstm, dec_embeddings, 
            target_vocab_to_int['<GO>'], target_vocab_to_int['<EOS>'], 
            max_target_sequence_length, target_vocab_size, 
            dense_layer, batch_size, keep_prob)
    
    return train_decoder_output, inference_decoder_output

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    # ran into a couple of errors took help from
    # (https://discussions.udacity.com/t/def-seq2seq-model/277476)
    
    output, state = encoding_layer(input_data, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   enc_embedding_size)
    
    processed_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    training_decoder_output, inference_decoder_output = decoding_layer(processed_input, state,
                   target_sequence_length, max_target_sentence_length,
                   rnn_size, num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, dec_embedding_size)
    
    return training_decoder_output, inference_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 512
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 30
decoding_embedding_size = 30
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.75
display_step = True

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    1/1077 - Train Accuracy: 0.2379, Validation Accuracy: 0.3242, Loss: 5.0471
# Epoch   0 Batch    2/1077 - Train Accuracy: 0.2463, Validation Accuracy: 0.3366, Loss: 5.5959
# Epoch   0 Batch    3/1077 - Train Accuracy: 0.2766, Validation Accuracy: 0.3469, Loss: 4.2373
# Epoch   0 Batch    4/1077 - Train Accuracy: 0.2750, Validation Accuracy: 0.3423, Loss: 4.4240
# Epoch   0 Batch    5/1077 - Train Accuracy: 0.3031, Validation Accuracy: 0.3462, Loss: 4.0399
# Epoch   0 Batch    6/1077 - Train Accuracy: 0.2930, Validation Accuracy: 0.3498, Loss: 3.7145
# Epoch   0 Batch    7/1077 - Train Accuracy: 0.2742, Validation Accuracy: 0.3498, Loss: 3.7257
# Epoch   0 Batch    8/1077 - Train Accuracy: 0.3113, Validation Accuracy: 0.3757, Loss: 3.6304
# Epoch   0 Batch    9/1077 - Train Accuracy: 0.3180, Validation Accuracy: 0.3789, Loss: 3.3906
# Epoch   0 Batch   10/1077 - Train Accuracy: 0.2932, Validation Accuracy: 0.3874, Loss: 3.5287
# Epoch   0 Batch   11/1077 - Train Accuracy: 0.3449, Validation Accuracy: 0.3892, Loss: 3.2268
# Epoch   0 Batch   12/1077 - Train Accuracy: 0.3039, Validation Accuracy: 0.3778, Loss: 3.2448
# Epoch   0 Batch   13/1077 - Train Accuracy: 0.3471, Validation Accuracy: 0.3761, Loss: 3.0087
# Epoch   0 Batch   14/1077 - Train Accuracy: 0.3359, Validation Accuracy: 0.3796, Loss: 2.9915
# Epoch   0 Batch   15/1077 - Train Accuracy: 0.3496, Validation Accuracy: 0.4087, Loss: 3.0390
# Epoch   0 Batch   16/1077 - Train Accuracy: 0.3770, Validation Accuracy: 0.4158, Loss: 2.9831
# Epoch   0 Batch   17/1077 - Train Accuracy: 0.3836, Validation Accuracy: 0.4244, Loss: 2.8573
# Epoch   0 Batch   18/1077 - Train Accuracy: 0.3672, Validation Accuracy: 0.4254, Loss: 2.9012
# Epoch   0 Batch   19/1077 - Train Accuracy: 0.4066, Validation Accuracy: 0.4425, Loss: 2.7884
# Epoch   0 Batch   20/1077 - Train Accuracy: 0.3984, Validation Accuracy: 0.4577, Loss: 2.7503
# Epoch   0 Batch   21/1077 - Train Accuracy: 0.3840, Validation Accuracy: 0.4602, Loss: 2.8674
# Epoch   0 Batch   22/1077 - Train Accuracy: 0.3863, Validation Accuracy: 0.4517, Loss: 2.7904
# Epoch   0 Batch   23/1077 - Train Accuracy: 0.3945, Validation Accuracy: 0.4521, Loss: 2.7953
# Epoch   0 Batch   24/1077 - Train Accuracy: 0.3855, Validation Accuracy: 0.4439, Loss: 2.6865
# Epoch   0 Batch   25/1077 - Train Accuracy: 0.3840, Validation Accuracy: 0.4368, Loss: 2.7494
# Epoch   0 Batch   26/1077 - Train Accuracy: 0.3754, Validation Accuracy: 0.4478, Loss: 2.7235
# Epoch   0 Batch   27/1077 - Train Accuracy: 0.4301, Validation Accuracy: 0.4595, Loss: 2.4566
# Epoch   0 Batch   28/1077 - Train Accuracy: 0.3984, Validation Accuracy: 0.4567, Loss: 2.5531
# Epoch   0 Batch   29/1077 - Train Accuracy: 0.4086, Validation Accuracy: 0.4606, Loss: 2.5808
# Epoch   0 Batch   30/1077 - Train Accuracy: 0.4047, Validation Accuracy: 0.4631, Loss: 2.5732
# Epoch   0 Batch   31/1077 - Train Accuracy: 0.4023, Validation Accuracy: 0.4599, Loss: 2.6137
# Epoch   0 Batch   32/1077 - Train Accuracy: 0.4498, Validation Accuracy: 0.4755, Loss: 2.3913
# Epoch   0 Batch   33/1077 - Train Accuracy: 0.4565, Validation Accuracy: 0.4727, Loss: 2.4061
# Epoch   0 Batch   34/1077 - Train Accuracy: 0.4215, Validation Accuracy: 0.4833, Loss: 2.4853
# Epoch   0 Batch   35/1077 - Train Accuracy: 0.4391, Validation Accuracy: 0.4901, Loss: 2.4728
# Epoch   0 Batch   36/1077 - Train Accuracy: 0.4219, Validation Accuracy: 0.4499, Loss: 2.4601
# Epoch   0 Batch   37/1077 - Train Accuracy: 0.4254, Validation Accuracy: 0.4798, Loss: 2.5779
# Epoch   0 Batch   38/1077 - Train Accuracy: 0.3668, Validation Accuracy: 0.4595, Loss: 2.6999
# Epoch   0 Batch   39/1077 - Train Accuracy: 0.3953, Validation Accuracy: 0.4659, Loss: 2.5783
# Epoch   0 Batch   40/1077 - Train Accuracy: 0.4066, Validation Accuracy: 0.4489, Loss: 2.4814
# Epoch   0 Batch   41/1077 - Train Accuracy: 0.4438, Validation Accuracy: 0.4769, Loss: 2.4093
# Epoch   0 Batch   42/1077 - Train Accuracy: 0.4246, Validation Accuracy: 0.4847, Loss: 2.3881
# Epoch   0 Batch   43/1077 - Train Accuracy: 0.4206, Validation Accuracy: 0.4794, Loss: 2.3962
# Epoch   0 Batch   44/1077 - Train Accuracy: 0.3705, Validation Accuracy: 0.4759, Loss: 2.5789
# Epoch   0 Batch   45/1077 - Train Accuracy: 0.3980, Validation Accuracy: 0.4719, Loss: 2.4830
# Epoch   0 Batch   46/1077 - Train Accuracy: 0.3964, Validation Accuracy: 0.4723, Loss: 2.4738
# Epoch   0 Batch   47/1077 - Train Accuracy: 0.4332, Validation Accuracy: 0.4833, Loss: 2.3606
# Epoch   0 Batch   48/1077 - Train Accuracy: 0.4289, Validation Accuracy: 0.4684, Loss: 2.4036
# Epoch   0 Batch   49/1077 - Train Accuracy: 0.4144, Validation Accuracy: 0.4755, Loss: 2.4034
# Epoch   0 Batch   50/1077 - Train Accuracy: 0.4043, Validation Accuracy: 0.4897, Loss: 2.4378
# Epoch   0 Batch   51/1077 - Train Accuracy: 0.4398, Validation Accuracy: 0.4830, Loss: 2.2991
# Epoch   0 Batch   52/1077 - Train Accuracy: 0.4164, Validation Accuracy: 0.4830, Loss: 2.4043
# Epoch   0 Batch   53/1077 - Train Accuracy: 0.4268, Validation Accuracy: 0.4865, Loss: 2.3435
# Epoch   0 Batch   54/1077 - Train Accuracy: 0.4160, Validation Accuracy: 0.5000, Loss: 2.4196
# Epoch   0 Batch   55/1077 - Train Accuracy: 0.4738, Validation Accuracy: 0.5064, Loss: 2.1916
# Epoch   0 Batch   56/1077 - Train Accuracy: 0.4523, Validation Accuracy: 0.4915, Loss: 2.2714
# Epoch   0 Batch   57/1077 - Train Accuracy: 0.5114, Validation Accuracy: 0.4975, Loss: 1.9992
# Epoch   0 Batch   58/1077 - Train Accuracy: 0.4680, Validation Accuracy: 0.5107, Loss: 2.2109
# Epoch   0 Batch   59/1077 - Train Accuracy: 0.4149, Validation Accuracy: 0.5053, Loss: 2.3060
# Epoch   0 Batch   60/1077 - Train Accuracy: 0.4691, Validation Accuracy: 0.5018, Loss: 2.1946
# Epoch   0 Batch   61/1077 - Train Accuracy: 0.4391, Validation Accuracy: 0.4915, Loss: 2.2106
# Epoch   0 Batch   62/1077 - Train Accuracy: 0.4178, Validation Accuracy: 0.4996, Loss: 2.2918
# Epoch   0 Batch   63/1077 - Train Accuracy: 0.4665, Validation Accuracy: 0.4915, Loss: 2.0436
# Epoch   0 Batch   64/1077 - Train Accuracy: 0.4453, Validation Accuracy: 0.4940, Loss: 2.2740
# Epoch   0 Batch   65/1077 - Train Accuracy: 0.4124, Validation Accuracy: 0.4798, Loss: 2.2761
# Epoch   0 Batch   66/1077 - Train Accuracy: 0.4386, Validation Accuracy: 0.4979, Loss: 2.1234
# Epoch   0 Batch   67/1077 - Train Accuracy: 0.4680, Validation Accuracy: 0.4957, Loss: 1.9955
# Epoch   0 Batch   68/1077 - Train Accuracy: 0.4344, Validation Accuracy: 0.5135, Loss: 2.2150
# Epoch   0 Batch   69/1077 - Train Accuracy: 0.4875, Validation Accuracy: 0.5149, Loss: 2.0768
# Epoch   0 Batch   70/1077 - Train Accuracy: 0.4408, Validation Accuracy: 0.5096, Loss: 2.1053
# Epoch   0 Batch   71/1077 - Train Accuracy: 0.4520, Validation Accuracy: 0.5146, Loss: 2.0573
# Epoch   0 Batch   72/1077 - Train Accuracy: 0.4707, Validation Accuracy: 0.5266, Loss: 2.0230
# Epoch   0 Batch   73/1077 - Train Accuracy: 0.4547, Validation Accuracy: 0.5167, Loss: 2.0656
# Epoch   0 Batch   74/1077 - Train Accuracy: 0.4754, Validation Accuracy: 0.5220, Loss: 1.9241
# Epoch   0 Batch   75/1077 - Train Accuracy: 0.4660, Validation Accuracy: 0.5007, Loss: 1.9169
# Epoch   0 Batch   76/1077 - Train Accuracy: 0.4551, Validation Accuracy: 0.5036, Loss: 1.9799
# Epoch   0 Batch   77/1077 - Train Accuracy: 0.4352, Validation Accuracy: 0.5028, Loss: 2.0271
# Epoch   0 Batch   78/1077 - Train Accuracy: 0.4383, Validation Accuracy: 0.5241, Loss: 2.1115
# Epoch   0 Batch   79/1077 - Train Accuracy: 0.4465, Validation Accuracy: 0.5075, Loss: 1.9599
# Epoch   0 Batch   80/1077 - Train Accuracy: 0.4719, Validation Accuracy: 0.5302, Loss: 1.9940
# Epoch   0 Batch   81/1077 - Train Accuracy: 0.4938, Validation Accuracy: 0.5238, Loss: 1.8988
# Epoch   0 Batch   82/1077 - Train Accuracy: 0.5156, Validation Accuracy: 0.5167, Loss: 1.7280
# Epoch   0 Batch   83/1077 - Train Accuracy: 0.4293, Validation Accuracy: 0.5075, Loss: 2.0175
# Epoch   0 Batch   84/1077 - Train Accuracy: 0.4789, Validation Accuracy: 0.5227, Loss: 1.9278
# Epoch   0 Batch   85/1077 - Train Accuracy: 0.4820, Validation Accuracy: 0.5188, Loss: 1.8149
# Epoch   0 Batch   86/1077 - Train Accuracy: 0.4598, Validation Accuracy: 0.5110, Loss: 1.9380
# Epoch   0 Batch   87/1077 - Train Accuracy: 0.4559, Validation Accuracy: 0.5060, Loss: 1.9066
# Epoch   0 Batch   88/1077 - Train Accuracy: 0.4859, Validation Accuracy: 0.5241, Loss: 1.8729
# Epoch   0 Batch   89/1077 - Train Accuracy: 0.4406, Validation Accuracy: 0.5082, Loss: 1.9289
# Epoch   0 Batch   90/1077 - Train Accuracy: 0.4570, Validation Accuracy: 0.5110, Loss: 1.9368
# Epoch   0 Batch   91/1077 - Train Accuracy: 0.5134, Validation Accuracy: 0.5167, Loss: 1.7014
# Epoch   0 Batch   92/1077 - Train Accuracy: 0.4598, Validation Accuracy: 0.4915, Loss: 1.8048
# Epoch   0 Batch   93/1077 - Train Accuracy: 0.4441, Validation Accuracy: 0.4979, Loss: 1.8452
# Epoch   0 Batch   94/1077 - Train Accuracy: 0.4754, Validation Accuracy: 0.5053, Loss: 1.7879
# Epoch   0 Batch   95/1077 - Train Accuracy: 0.4944, Validation Accuracy: 0.5210, Loss: 1.7785
# Epoch   0 Batch   96/1077 - Train Accuracy: 0.4547, Validation Accuracy: 0.5021, Loss: 1.8010
# Epoch   0 Batch   97/1077 - Train Accuracy: 0.4594, Validation Accuracy: 0.4968, Loss: 1.8007
# Epoch   0 Batch   98/1077 - Train Accuracy: 0.4885, Validation Accuracy: 0.4893, Loss: 1.6915
# Epoch   0 Batch   99/1077 - Train Accuracy: 0.4262, Validation Accuracy: 0.4954, Loss: 1.8505
# Epoch   0 Batch  100/1077 - Train Accuracy: 0.4805, Validation Accuracy: 0.5185, Loss: 1.7336
# Epoch   0 Batch  101/1077 - Train Accuracy: 0.3707, Validation Accuracy: 0.4510, Loss: 1.7599
# Epoch   0 Batch  102/1077 - Train Accuracy: 0.4809, Validation Accuracy: 0.5117, Loss: 2.1387
# Epoch   0 Batch  103/1077 - Train Accuracy: 0.3898, Validation Accuracy: 0.4688, Loss: 1.8824
# Epoch   0 Batch  104/1077 - Train Accuracy: 0.3660, Validation Accuracy: 0.4751, Loss: 2.2404
# Epoch   0 Batch  105/1077 - Train Accuracy: 0.4195, Validation Accuracy: 0.4581, Loss: 1.8188
# Epoch   0 Batch  106/1077 - Train Accuracy: 0.4453, Validation Accuracy: 0.5114, Loss: 2.0745
# Epoch   0 Batch  107/1077 - Train Accuracy: 0.4888, Validation Accuracy: 0.5000, Loss: 1.7272
# Epoch   0 Batch  108/1077 - Train Accuracy: 0.5249, Validation Accuracy: 0.5085, Loss: 1.6884
# Epoch   0 Batch  109/1077 - Train Accuracy: 0.4629, Validation Accuracy: 0.4943, Loss: 1.8479
# Epoch   0 Batch  110/1077 - Train Accuracy: 0.4320, Validation Accuracy: 0.4620, Loss: 1.6801
# Epoch   0 Batch  111/1077 - Train Accuracy: 0.4219, Validation Accuracy: 0.4766, Loss: 1.8892
# Epoch   0 Batch  112/1077 - Train Accuracy: 0.4508, Validation Accuracy: 0.5103, Loss: 1.8494
# Epoch   0 Batch  113/1077 - Train Accuracy: 0.4672, Validation Accuracy: 0.5245, Loss: 1.8141
# Epoch   0 Batch  114/1077 - Train Accuracy: 0.4937, Validation Accuracy: 0.5323, Loss: 1.7853
# Epoch   0 Batch  115/1077 - Train Accuracy: 0.4391, Validation Accuracy: 0.4986, Loss: 1.7630
# Epoch   0 Batch  116/1077 - Train Accuracy: 0.4000, Validation Accuracy: 0.4901, Loss: 1.8439
# Epoch   0 Batch  117/1077 - Train Accuracy: 0.4055, Validation Accuracy: 0.4996, Loss: 1.9171
# Epoch   0 Batch  118/1077 - Train Accuracy: 0.4202, Validation Accuracy: 0.5110, Loss: 1.7838
# Epoch   0 Batch  119/1077 - Train Accuracy: 0.4707, Validation Accuracy: 0.5021, Loss: 1.6812
# Epoch   0 Batch  120/1077 - Train Accuracy: 0.4598, Validation Accuracy: 0.5032, Loss: 1.7109
# Epoch   0 Batch  121/1077 - Train Accuracy: 0.4453, Validation Accuracy: 0.4865, Loss: 1.6437
# Epoch   0 Batch  122/1077 - Train Accuracy: 0.4395, Validation Accuracy: 0.4826, Loss: 1.7080
# Epoch   0 Batch  123/1077 - Train Accuracy: 0.4559, Validation Accuracy: 0.4915, Loss: 1.6743
# Epoch   0 Batch  124/1077 - Train Accuracy: 0.4562, Validation Accuracy: 0.5160, Loss: 1.6416
# Epoch   0 Batch  125/1077 - Train Accuracy: 0.4896, Validation Accuracy: 0.5234, Loss: 1.6125
# Epoch   0 Batch  126/1077 - Train Accuracy: 0.4457, Validation Accuracy: 0.4940, Loss: 1.5871
# Epoch   0 Batch  127/1077 - Train Accuracy: 0.4223, Validation Accuracy: 0.4677, Loss: 1.6144
# Epoch   0 Batch  128/1077 - Train Accuracy: 0.4609, Validation Accuracy: 0.4680, Loss: 1.5459
# Epoch   0 Batch  129/1077 - Train Accuracy: 0.4684, Validation Accuracy: 0.4943, Loss: 1.6890
# Epoch   0 Batch  130/1077 - Train Accuracy: 0.4862, Validation Accuracy: 0.5163, Loss: 1.5355
# Epoch   0 Batch  131/1077 - Train Accuracy: 0.4793, Validation Accuracy: 0.5263, Loss: 1.6394
# Epoch   0 Batch  132/1077 - Train Accuracy: 0.4469, Validation Accuracy: 0.5103, Loss: 1.6729
# Epoch   0 Batch  133/1077 - Train Accuracy: 0.4433, Validation Accuracy: 0.5128, Loss: 1.5991
# Epoch   0 Batch  134/1077 - Train Accuracy: 0.4781, Validation Accuracy: 0.5213, Loss: 1.5513
# Epoch   0 Batch  135/1077 - Train Accuracy: 0.4667, Validation Accuracy: 0.5245, Loss: 1.6688
# Epoch   0 Batch  136/1077 - Train Accuracy: 0.4863, Validation Accuracy: 0.5178, Loss: 1.5526
# Epoch   0 Batch  137/1077 - Train Accuracy: 0.4948, Validation Accuracy: 0.5057, Loss: 1.4676
# Epoch   0 Batch  138/1077 - Train Accuracy: 0.4109, Validation Accuracy: 0.4826, Loss: 1.5234
# Epoch   0 Batch  139/1077 - Train Accuracy: 0.4426, Validation Accuracy: 0.4783, Loss: 1.5234
# Epoch   0 Batch  140/1077 - Train Accuracy: 0.4149, Validation Accuracy: 0.4801, Loss: 1.6400
# Epoch   0 Batch  141/1077 - Train Accuracy: 0.4742, Validation Accuracy: 0.5131, Loss: 1.5582
# Epoch   0 Batch  142/1077 - Train Accuracy: 0.5015, Validation Accuracy: 0.5245, Loss: 1.4565
# Epoch   0 Batch  143/1077 - Train Accuracy: 0.4777, Validation Accuracy: 0.5053, Loss: 1.5579
# Epoch   0 Batch  144/1077 - Train Accuracy: 0.3910, Validation Accuracy: 0.4744, Loss: 1.5897
# Epoch   0 Batch  145/1077 - Train Accuracy: 0.4539, Validation Accuracy: 0.4872, Loss: 1.5374
# Epoch   0 Batch  146/1077 - Train Accuracy: 0.5082, Validation Accuracy: 0.5107, Loss: 1.4890
# Epoch   0 Batch  147/1077 - Train Accuracy: 0.4457, Validation Accuracy: 0.5071, Loss: 1.5475
# Epoch   0 Batch  148/1077 - Train Accuracy: 0.4609, Validation Accuracy: 0.5071, Loss: 1.4946
# Epoch   0 Batch  149/1077 - Train Accuracy: 0.4340, Validation Accuracy: 0.4979, Loss: 1.5197
# Epoch   0 Batch  150/1077 - Train Accuracy: 0.5030, Validation Accuracy: 0.5103, Loss: 1.3888
# Epoch   0 Batch  151/1077 - Train Accuracy: 0.5000, Validation Accuracy: 0.5195, Loss: 1.4310
# Epoch   0 Batch  152/1077 - Train Accuracy: 0.4844, Validation Accuracy: 0.5085, Loss: 1.5036
# Epoch   0 Batch  153/1077 - Train Accuracy: 0.4715, Validation Accuracy: 0.5114, Loss: 1.5105
# Epoch   0 Batch  154/1077 - Train Accuracy: 0.4330, Validation Accuracy: 0.5092, Loss: 1.5194
# Epoch   0 Batch  155/1077 - Train Accuracy: 0.4617, Validation Accuracy: 0.5138, Loss: 1.4581
# Epoch   0 Batch  156/1077 - Train Accuracy: 0.4750, Validation Accuracy: 0.5277, Loss: 1.4438
# Epoch   0 Batch  157/1077 - Train Accuracy: 0.4996, Validation Accuracy: 0.5245, Loss: 1.4258
# Epoch   0 Batch  158/1077 - Train Accuracy: 0.5004, Validation Accuracy: 0.5252, Loss: 1.4420
# Epoch   0 Batch  159/1077 - Train Accuracy: 0.5019, Validation Accuracy: 0.5174, Loss: 1.3561
# Epoch   0 Batch  160/1077 - Train Accuracy: 0.5086, Validation Accuracy: 0.5099, Loss: 1.3887
# Epoch   0 Batch  161/1077 - Train Accuracy: 0.4699, Validation Accuracy: 0.5131, Loss: 1.4537
# Epoch   0 Batch  162/1077 - Train Accuracy: 0.4859, Validation Accuracy: 0.5149, Loss: 1.4308
# Epoch   0 Batch  163/1077 - Train Accuracy: 0.4334, Validation Accuracy: 0.5064, Loss: 1.4677
# Epoch   0 Batch  164/1077 - Train Accuracy: 0.4645, Validation Accuracy: 0.5067, Loss: 1.3978
# Epoch   0 Batch  165/1077 - Train Accuracy: 0.4516, Validation Accuracy: 0.5110, Loss: 1.3869
# Epoch   0 Batch  166/1077 - Train Accuracy: 0.5016, Validation Accuracy: 0.5057, Loss: 1.3717
# Epoch   0 Batch  167/1077 - Train Accuracy: 0.4844, Validation Accuracy: 0.5263, Loss: 1.4313
# Epoch   0 Batch  168/1077 - Train Accuracy: 0.4737, Validation Accuracy: 0.5291, Loss: 1.4375
# Epoch   0 Batch  169/1077 - Train Accuracy: 0.5335, Validation Accuracy: 0.5210, Loss: 1.3496
# Epoch   0 Batch  170/1077 - Train Accuracy: 0.4723, Validation Accuracy: 0.5213, Loss: 1.4166
# Epoch   0 Batch  171/1077 - Train Accuracy: 0.5387, Validation Accuracy: 0.5170, Loss: 1.2863
# Epoch   0 Batch  172/1077 - Train Accuracy: 0.5175, Validation Accuracy: 0.5213, Loss: 1.2797
# Epoch   0 Batch  173/1077 - Train Accuracy: 0.4655, Validation Accuracy: 0.5312, Loss: 1.4350
# Epoch   0 Batch  174/1077 - Train Accuracy: 0.5234, Validation Accuracy: 0.5376, Loss: 1.3203
# Epoch   0 Batch  175/1077 - Train Accuracy: 0.5117, Validation Accuracy: 0.5281, Loss: 1.3390
# Epoch   0 Batch  176/1077 - Train Accuracy: 0.4809, Validation Accuracy: 0.5355, Loss: 1.3394
# Epoch   0 Batch  177/1077 - Train Accuracy: 0.4811, Validation Accuracy: 0.5256, Loss: 1.4006
# Epoch   0 Batch  178/1077 - Train Accuracy: 0.5051, Validation Accuracy: 0.5107, Loss: 1.3329
# Epoch   0 Batch  179/1077 - Train Accuracy: 0.5173, Validation Accuracy: 0.5430, Loss: 1.3736
# Epoch   0 Batch  180/1077 - Train Accuracy: 0.5094, Validation Accuracy: 0.5529, Loss: 1.3463
# Epoch   0 Batch  181/1077 - Train Accuracy: 0.5129, Validation Accuracy: 0.5263, Loss: 1.3402
# Epoch   0 Batch  182/1077 - Train Accuracy: 0.5130, Validation Accuracy: 0.5376, Loss: 1.3145
# Epoch   0 Batch  183/1077 - Train Accuracy: 0.4902, Validation Accuracy: 0.5483, Loss: 1.3657
# Epoch   0 Batch  184/1077 - Train Accuracy: 0.5395, Validation Accuracy: 0.5387, Loss: 1.2597
# Epoch   0 Batch  185/1077 - Train Accuracy: 0.4918, Validation Accuracy: 0.5384, Loss: 1.3243
# Epoch   0 Batch  186/1077 - Train Accuracy: 0.4860, Validation Accuracy: 0.5238, Loss: 1.3164
# Epoch   0 Batch  187/1077 - Train Accuracy: 0.5094, Validation Accuracy: 0.5202, Loss: 1.2812
# Epoch   0 Batch  188/1077 - Train Accuracy: 0.5152, Validation Accuracy: 0.5451, Loss: 1.2935
# Epoch   0 Batch  189/1077 - Train Accuracy: 0.5195, Validation Accuracy: 0.5437, Loss: 1.3027
# Epoch   0 Batch  190/1077 - Train Accuracy: 0.5211, Validation Accuracy: 0.5380, Loss: 1.2564
# Epoch   0 Batch  191/1077 - Train Accuracy: 0.5490, Validation Accuracy: 0.5348, Loss: 1.1542
# Epoch   0 Batch  192/1077 - Train Accuracy: 0.5359, Validation Accuracy: 0.5415, Loss: 1.2569
# Epoch   0 Batch  193/1077 - Train Accuracy: 0.5180, Validation Accuracy: 0.5490, Loss: 1.2378
# Epoch   0 Batch  194/1077 - Train Accuracy: 0.5324, Validation Accuracy: 0.5415, Loss: 1.1710
# Epoch   0 Batch  195/1077 - Train Accuracy: 0.5016, Validation Accuracy: 0.5518, Loss: 1.2592
# Epoch   0 Batch  196/1077 - Train Accuracy: 0.5340, Validation Accuracy: 0.5522, Loss: 1.2198
# Epoch   0 Batch  197/1077 - Train Accuracy: 0.5227, Validation Accuracy: 0.5469, Loss: 1.2260
# Epoch   0 Batch  198/1077 - Train Accuracy: 0.5446, Validation Accuracy: 0.5430, Loss: 1.1298
# Epoch   0 Batch  199/1077 - Train Accuracy: 0.5176, Validation Accuracy: 0.5359, Loss: 1.2347
# Epoch   0 Batch  200/1077 - Train Accuracy: 0.4895, Validation Accuracy: 0.5334, Loss: 1.2856
# Epoch   0 Batch  201/1077 - Train Accuracy: 0.5176, Validation Accuracy: 0.5543, Loss: 1.1664
# Epoch   0 Batch  202/1077 - Train Accuracy: 0.5406, Validation Accuracy: 0.5529, Loss: 1.2308
# Epoch   0 Batch  203/1077 - Train Accuracy: 0.5207, Validation Accuracy: 0.5618, Loss: 1.2286
# Epoch   0 Batch  204/1077 - Train Accuracy: 0.5004, Validation Accuracy: 0.5526, Loss: 1.2255
# Epoch   0 Batch  205/1077 - Train Accuracy: 0.5488, Validation Accuracy: 0.5518, Loss: 1.2074
# Epoch   0 Batch  206/1077 - Train Accuracy: 0.5188, Validation Accuracy: 0.5700, Loss: 1.2198
# Epoch   0 Batch  207/1077 - Train Accuracy: 0.4926, Validation Accuracy: 0.5458, Loss: 1.2761
# Epoch   0 Batch  208/1077 - Train Accuracy: 0.4851, Validation Accuracy: 0.5309, Loss: 1.2116
# Epoch   0 Batch  209/1077 - Train Accuracy: 0.5629, Validation Accuracy: 0.5710, Loss: 1.1836
# Epoch   0 Batch  210/1077 - Train Accuracy: 0.5666, Validation Accuracy: 0.5646, Loss: 1.2087
# Epoch   0 Batch  211/1077 - Train Accuracy: 0.4719, Validation Accuracy: 0.5057, Loss: 1.2205
# Epoch   0 Batch  212/1077 - Train Accuracy: 0.5219, Validation Accuracy: 0.5444, Loss: 1.1870
# Epoch   0 Batch  213/1077 - Train Accuracy: 0.5547, Validation Accuracy: 0.5352, Loss: 1.1269
# Epoch   0 Batch  214/1077 - Train Accuracy: 0.5273, Validation Accuracy: 0.5763, Loss: 1.1797
# Epoch   0 Batch  215/1077 - Train Accuracy: 0.4750, Validation Accuracy: 0.5497, Loss: 1.2234
# Epoch   0 Batch  216/1077 - Train Accuracy: 0.5004, Validation Accuracy: 0.5582, Loss: 1.2185
# Epoch   0 Batch  217/1077 - Train Accuracy: 0.5668, Validation Accuracy: 0.5710, Loss: 1.1403
# Epoch   0 Batch  218/1077 - Train Accuracy: 0.5424, Validation Accuracy: 0.5756, Loss: 1.2482
# Epoch   0 Batch  219/1077 - Train Accuracy: 0.5406, Validation Accuracy: 0.5312, Loss: 1.1028
# Epoch   0 Batch  220/1077 - Train Accuracy: 0.4959, Validation Accuracy: 0.5526, Loss: 1.1796
# Epoch   0 Batch  221/1077 - Train Accuracy: 0.5646, Validation Accuracy: 0.5643, Loss: 1.1490
# Epoch   0 Batch  222/1077 - Train Accuracy: 0.5070, Validation Accuracy: 0.5625, Loss: 1.2395
# Epoch   0 Batch  223/1077 - Train Accuracy: 0.5480, Validation Accuracy: 0.5643, Loss: 1.0888
# Epoch   0 Batch  224/1077 - Train Accuracy: 0.5414, Validation Accuracy: 0.5643, Loss: 1.1510
# Epoch   0 Batch  225/1077 - Train Accuracy: 0.4941, Validation Accuracy: 0.5511, Loss: 1.1397
# Epoch   0 Batch  226/1077 - Train Accuracy: 0.5398, Validation Accuracy: 0.5565, Loss: 1.1373
# Epoch   0 Batch  227/1077 - Train Accuracy: 0.5078, Validation Accuracy: 0.5604, Loss: 1.1776
# Epoch   0 Batch  228/1077 - Train Accuracy: 0.5832, Validation Accuracy: 0.5586, Loss: 1.0833
# Epoch   0 Batch  229/1077 - Train Accuracy: 0.5555, Validation Accuracy: 0.5572, Loss: 1.0873
# Epoch   0 Batch  230/1077 - Train Accuracy: 0.5484, Validation Accuracy: 0.5554, Loss: 1.0602
# Epoch   0 Batch  231/1077 - Train Accuracy: 0.5512, Validation Accuracy: 0.5721, Loss: 1.0804
# Epoch   0 Batch  232/1077 - Train Accuracy: 0.5399, Validation Accuracy: 0.5795, Loss: 1.1267
# Epoch   0 Batch  233/1077 - Train Accuracy: 0.5437, Validation Accuracy: 0.5771, Loss: 1.1647
# Epoch   0 Batch  234/1077 - Train Accuracy: 0.5833, Validation Accuracy: 0.5771, Loss: 1.0753
# Epoch   0 Batch  235/1077 - Train Accuracy: 0.5778, Validation Accuracy: 0.5668, Loss: 1.0049
# Epoch   0 Batch  236/1077 - Train Accuracy: 0.5367, Validation Accuracy: 0.5806, Loss: 1.1158
# Epoch   0 Batch  237/1077 - Train Accuracy: 0.5830, Validation Accuracy: 0.5749, Loss: 1.0008
# Epoch   0 Batch  238/1077 - Train Accuracy: 0.5563, Validation Accuracy: 0.5678, Loss: 1.0939
# Epoch   0 Batch  239/1077 - Train Accuracy: 0.5565, Validation Accuracy: 0.5650, Loss: 0.9833
# Epoch   0 Batch  240/1077 - Train Accuracy: 0.5461, Validation Accuracy: 0.5774, Loss: 1.0662
# Epoch   0 Batch  241/1077 - Train Accuracy: 0.5645, Validation Accuracy: 0.5721, Loss: 1.0086
# Epoch   0 Batch  242/1077 - Train Accuracy: 0.5414, Validation Accuracy: 0.5806, Loss: 1.0844
# Epoch   0 Batch  243/1077 - Train Accuracy: 0.5070, Validation Accuracy: 0.5760, Loss: 1.0683
# Epoch   0 Batch  244/1077 - Train Accuracy: 0.6165, Validation Accuracy: 0.5803, Loss: 0.9894
# Epoch   0 Batch  245/1077 - Train Accuracy: 0.5439, Validation Accuracy: 0.5778, Loss: 1.0069
# Epoch   0 Batch  246/1077 - Train Accuracy: 0.5422, Validation Accuracy: 0.5632, Loss: 1.0441
# Epoch   0 Batch  247/1077 - Train Accuracy: 0.5945, Validation Accuracy: 0.5671, Loss: 0.9770
# Epoch   0 Batch  248/1077 - Train Accuracy: 0.5531, Validation Accuracy: 0.5771, Loss: 1.0066
# Epoch   0 Batch  249/1077 - Train Accuracy: 0.5340, Validation Accuracy: 0.5572, Loss: 1.0030
# Epoch   0 Batch  250/1077 - Train Accuracy: 0.5533, Validation Accuracy: 0.5728, Loss: 0.9613
# Epoch   0 Batch  251/1077 - Train Accuracy: 0.5606, Validation Accuracy: 0.5632, Loss: 1.0164
# Epoch   0 Batch  252/1077 - Train Accuracy: 0.5359, Validation Accuracy: 0.5788, Loss: 1.0400
# Epoch   0 Batch  253/1077 - Train Accuracy: 0.5788, Validation Accuracy: 0.5863, Loss: 0.9990
# Epoch   0 Batch  254/1077 - Train Accuracy: 0.5457, Validation Accuracy: 0.5735, Loss: 1.0349
# Epoch   0 Batch  255/1077 - Train Accuracy: 0.5512, Validation Accuracy: 0.5792, Loss: 1.0380
# Epoch   0 Batch  256/1077 - Train Accuracy: 0.5320, Validation Accuracy: 0.5788, Loss: 1.0905
# Epoch   0 Batch  257/1077 - Train Accuracy: 0.5863, Validation Accuracy: 0.5820, Loss: 0.9757
# Epoch   0 Batch  258/1077 - Train Accuracy: 0.5632, Validation Accuracy: 0.5724, Loss: 0.9911
# Epoch   0 Batch  259/1077 - Train Accuracy: 0.5441, Validation Accuracy: 0.5774, Loss: 1.0105
# Epoch   0 Batch  260/1077 - Train Accuracy: 0.5658, Validation Accuracy: 0.5646, Loss: 0.9518
# Epoch   0 Batch  261/1077 - Train Accuracy: 0.5543, Validation Accuracy: 0.5657, Loss: 0.9574
# Epoch   0 Batch  262/1077 - Train Accuracy: 0.5270, Validation Accuracy: 0.5522, Loss: 0.9652
# Epoch   0 Batch  263/1077 - Train Accuracy: 0.5742, Validation Accuracy: 0.5827, Loss: 0.9552
# Epoch   0 Batch  264/1077 - Train Accuracy: 0.5531, Validation Accuracy: 0.5820, Loss: 1.0160
# Epoch   0 Batch  265/1077 - Train Accuracy: 0.5398, Validation Accuracy: 0.5678, Loss: 1.0240
# Epoch   0 Batch  266/1077 - Train Accuracy: 0.5603, Validation Accuracy: 0.5781, Loss: 0.9775
# Epoch   0 Batch  267/1077 - Train Accuracy: 0.5455, Validation Accuracy: 0.5799, Loss: 0.9226
# Epoch   0 Batch  268/1077 - Train Accuracy: 0.5750, Validation Accuracy: 0.5799, Loss: 0.9995
# Epoch   0 Batch  269/1077 - Train Accuracy: 0.5041, Validation Accuracy: 0.5554, Loss: 1.0708
# Epoch   0 Batch  270/1077 - Train Accuracy: 0.5184, Validation Accuracy: 0.5586, Loss: 1.0493
# Epoch   0 Batch  271/1077 - Train Accuracy: 0.5668, Validation Accuracy: 0.5746, Loss: 0.9837
# Epoch   0 Batch  272/1077 - Train Accuracy: 0.5610, Validation Accuracy: 0.5732, Loss: 0.9613
# Epoch   0 Batch  273/1077 - Train Accuracy: 0.5554, Validation Accuracy: 0.5895, Loss: 0.9766
# Epoch   0 Batch  274/1077 - Train Accuracy: 0.5528, Validation Accuracy: 0.5689, Loss: 0.9650
# Epoch   0 Batch  275/1077 - Train Accuracy: 0.5580, Validation Accuracy: 0.5845, Loss: 0.9652
# Epoch   0 Batch  276/1077 - Train Accuracy: 0.5242, Validation Accuracy: 0.5895, Loss: 1.0467
# Epoch   0 Batch  277/1077 - Train Accuracy: 0.5673, Validation Accuracy: 0.5771, Loss: 0.9096
# Epoch   0 Batch  278/1077 - Train Accuracy: 0.5617, Validation Accuracy: 0.5888, Loss: 1.0293
# Epoch   0 Batch  279/1077 - Train Accuracy: 0.5547, Validation Accuracy: 0.5792, Loss: 1.0333
# Epoch   0 Batch  280/1077 - Train Accuracy: 0.5730, Validation Accuracy: 0.5817, Loss: 0.9995
# Epoch   0 Batch  281/1077 - Train Accuracy: 0.5344, Validation Accuracy: 0.5945, Loss: 1.0153
# Epoch   0 Batch  282/1077 - Train Accuracy: 0.5227, Validation Accuracy: 0.5881, Loss: 1.0643
# Epoch   0 Batch  283/1077 - Train Accuracy: 0.5633, Validation Accuracy: 0.5749, Loss: 0.9762
# Epoch   0 Batch  284/1077 - Train Accuracy: 0.5863, Validation Accuracy: 0.5881, Loss: 0.9898
# Epoch   0 Batch  285/1077 - Train Accuracy: 0.5964, Validation Accuracy: 0.5941, Loss: 0.9180
# Epoch   0 Batch  286/1077 - Train Accuracy: 0.5804, Validation Accuracy: 0.5653, Loss: 0.8741
# Epoch   0 Batch  287/1077 - Train Accuracy: 0.5879, Validation Accuracy: 0.5923, Loss: 0.9313
# Epoch   0 Batch  288/1077 - Train Accuracy: 0.5531, Validation Accuracy: 0.5835, Loss: 0.9477
# Epoch   0 Batch  289/1077 - Train Accuracy: 0.6027, Validation Accuracy: 0.5856, Loss: 0.9270
# Epoch   0 Batch  290/1077 - Train Accuracy: 0.5367, Validation Accuracy: 0.5806, Loss: 0.9773
# Epoch   0 Batch  291/1077 - Train Accuracy: 0.5197, Validation Accuracy: 0.5700, Loss: 0.9569
# Epoch   0 Batch  292/1077 - Train Accuracy: 0.5848, Validation Accuracy: 0.5909, Loss: 0.9399
# Epoch   0 Batch  293/1077 - Train Accuracy: 0.5336, Validation Accuracy: 0.5859, Loss: 0.9559
# Epoch   0 Batch  294/1077 - Train Accuracy: 0.5955, Validation Accuracy: 0.5891, Loss: 0.8738
# Epoch   0 Batch  295/1077 - Train Accuracy: 0.5535, Validation Accuracy: 0.5753, Loss: 1.0070
# Epoch   0 Batch  296/1077 - Train Accuracy: 0.5811, Validation Accuracy: 0.5714, Loss: 0.8687
# Epoch   0 Batch  297/1077 - Train Accuracy: 0.5559, Validation Accuracy: 0.5810, Loss: 0.9781
# Epoch   0 Batch  298/1077 - Train Accuracy: 0.5543, Validation Accuracy: 0.5810, Loss: 1.0020
# Epoch   0 Batch  299/1077 - Train Accuracy: 0.5645, Validation Accuracy: 0.5874, Loss: 0.8914
# Epoch   0 Batch  300/1077 - Train Accuracy: 0.5613, Validation Accuracy: 0.5874, Loss: 0.9517
# Epoch   0 Batch  301/1077 - Train Accuracy: 0.5676, Validation Accuracy: 0.6019, Loss: 0.8977
# Epoch   0 Batch  302/1077 - Train Accuracy: 0.6188, Validation Accuracy: 0.5909, Loss: 0.8914
# Epoch   0 Batch  303/1077 - Train Accuracy: 0.5609, Validation Accuracy: 0.5959, Loss: 0.9366
# Epoch   0 Batch  304/1077 - Train Accuracy: 0.5409, Validation Accuracy: 0.5838, Loss: 0.8739
# Epoch   0 Batch  305/1077 - Train Accuracy: 0.5852, Validation Accuracy: 0.5866, Loss: 0.9050
# Epoch   0 Batch  306/1077 - Train Accuracy: 0.5863, Validation Accuracy: 0.5806, Loss: 0.8650
# Epoch   0 Batch  307/1077 - Train Accuracy: 0.5618, Validation Accuracy: 0.5859, Loss: 0.8897
# Epoch   0 Batch  308/1077 - Train Accuracy: 0.5457, Validation Accuracy: 0.5959, Loss: 0.9544
# Epoch   0 Batch  309/1077 - Train Accuracy: 0.5811, Validation Accuracy: 0.5898, Loss: 0.8454
# Epoch   0 Batch  310/1077 - Train Accuracy: 0.5629, Validation Accuracy: 0.5820, Loss: 0.9070
# Epoch   0 Batch  311/1077 - Train Accuracy: 0.6198, Validation Accuracy: 0.5959, Loss: 0.8532
# Epoch   0 Batch  312/1077 - Train Accuracy: 0.6031, Validation Accuracy: 0.6005, Loss: 0.9293
# Epoch   0 Batch  313/1077 - Train Accuracy: 0.5391, Validation Accuracy: 0.5984, Loss: 0.9020
# Epoch   0 Batch  314/1077 - Train Accuracy: 0.5992, Validation Accuracy: 0.5938, Loss: 0.8579
# Epoch   0 Batch  315/1077 - Train Accuracy: 0.5804, Validation Accuracy: 0.5774, Loss: 0.8319
# Epoch   0 Batch  316/1077 - Train Accuracy: 0.5725, Validation Accuracy: 0.5891, Loss: 0.8553
# Epoch   0 Batch  317/1077 - Train Accuracy: 0.5810, Validation Accuracy: 0.5934, Loss: 0.9124
# Epoch   0 Batch  318/1077 - Train Accuracy: 0.5707, Validation Accuracy: 0.5842, Loss: 0.8721
# Epoch   0 Batch  319/1077 - Train Accuracy: 0.5617, Validation Accuracy: 0.5824, Loss: 0.8752
# Epoch   0 Batch  320/1077 - Train Accuracy: 0.5910, Validation Accuracy: 0.5863, Loss: 0.8696
# Epoch   0 Batch  321/1077 - Train Accuracy: 0.5867, Validation Accuracy: 0.5952, Loss: 0.8528
# Epoch   0 Batch  322/1077 - Train Accuracy: 0.5599, Validation Accuracy: 0.5909, Loss: 0.8454
# Epoch   0 Batch  323/1077 - Train Accuracy: 0.5730, Validation Accuracy: 0.5891, Loss: 0.9057
# Epoch   0 Batch  324/1077 - Train Accuracy: 0.5691, Validation Accuracy: 0.5838, Loss: 0.8772
# Epoch   0 Batch  325/1077 - Train Accuracy: 0.6150, Validation Accuracy: 0.5902, Loss: 0.8360
# Epoch   0 Batch  326/1077 - Train Accuracy: 0.6053, Validation Accuracy: 0.5870, Loss: 0.8546
# Epoch   0 Batch  327/1077 - Train Accuracy: 0.5566, Validation Accuracy: 0.5820, Loss: 0.8630
# Epoch   0 Batch  328/1077 - Train Accuracy: 0.5573, Validation Accuracy: 0.5739, Loss: 0.8872
# Epoch   0 Batch  329/1077 - Train Accuracy: 0.5449, Validation Accuracy: 0.5916, Loss: 0.9028
# Epoch   0 Batch  330/1077 - Train Accuracy: 0.6035, Validation Accuracy: 0.5863, Loss: 0.8647
# Epoch   0 Batch  331/1077 - Train Accuracy: 0.5477, Validation Accuracy: 0.5962, Loss: 0.8860
# Epoch   0 Batch  332/1077 - Train Accuracy: 0.5599, Validation Accuracy: 0.5888, Loss: 0.8011
# Epoch   0 Batch  333/1077 - Train Accuracy: 0.5991, Validation Accuracy: 0.5838, Loss: 0.8509
# Epoch   0 Batch  334/1077 - Train Accuracy: 0.5656, Validation Accuracy: 0.5938, Loss: 0.8846
# Epoch   0 Batch  335/1077 - Train Accuracy: 0.6086, Validation Accuracy: 0.5945, Loss: 0.8159
# Epoch   0 Batch  336/1077 - Train Accuracy: 0.5738, Validation Accuracy: 0.5994, Loss: 0.8653
# Epoch   0 Batch  337/1077 - Train Accuracy: 0.5406, Validation Accuracy: 0.5810, Loss: 0.9073
# Epoch   0 Batch  338/1077 - Train Accuracy: 0.5910, Validation Accuracy: 0.5813, Loss: 0.9102
# Epoch   0 Batch  339/1077 - Train Accuracy: 0.5738, Validation Accuracy: 0.5831, Loss: 0.8329
# Epoch   0 Batch  340/1077 - Train Accuracy: 0.5613, Validation Accuracy: 0.5898, Loss: 0.8475
# Epoch   0 Batch  341/1077 - Train Accuracy: 0.6145, Validation Accuracy: 0.5842, Loss: 0.8643
# Epoch   0 Batch  342/1077 - Train Accuracy: 0.5915, Validation Accuracy: 0.5941, Loss: 0.7795
# Epoch   0 Batch  343/1077 - Train Accuracy: 0.5762, Validation Accuracy: 0.5959, Loss: 0.8678
# Epoch   0 Batch  344/1077 - Train Accuracy: 0.6094, Validation Accuracy: 0.5898, Loss: 0.8270
# Epoch   0 Batch  345/1077 - Train Accuracy: 0.5841, Validation Accuracy: 0.5923, Loss: 0.8187
# Epoch   0 Batch  346/1077 - Train Accuracy: 0.5301, Validation Accuracy: 0.5771, Loss: 0.8415
# Epoch   0 Batch  347/1077 - Train Accuracy: 0.5714, Validation Accuracy: 0.5877, Loss: 0.8016
# Epoch   0 Batch  348/1077 - Train Accuracy: 0.5722, Validation Accuracy: 0.5835, Loss: 0.7951
# Epoch   0 Batch  349/1077 - Train Accuracy: 0.5359, Validation Accuracy: 0.5902, Loss: 0.8182
# Epoch   0 Batch  350/1077 - Train Accuracy: 0.5695, Validation Accuracy: 0.5661, Loss: 0.8686
# Epoch   0 Batch  351/1077 - Train Accuracy: 0.5263, Validation Accuracy: 0.5771, Loss: 0.8572
# Epoch   0 Batch  352/1077 - Train Accuracy: 0.5664, Validation Accuracy: 0.5675, Loss: 0.8158
# Epoch   0 Batch  353/1077 - Train Accuracy: 0.5436, Validation Accuracy: 0.5874, Loss: 0.9112
# Epoch   0 Batch  354/1077 - Train Accuracy: 0.5809, Validation Accuracy: 0.6126, Loss: 0.8509
# Epoch   0 Batch  355/1077 - Train Accuracy: 0.5908, Validation Accuracy: 0.6101, Loss: 0.7931
# Epoch   0 Batch  356/1077 - Train Accuracy: 0.5742, Validation Accuracy: 0.5945, Loss: 0.8198
# Epoch   0 Batch  357/1077 - Train Accuracy: 0.5949, Validation Accuracy: 0.5906, Loss: 0.7796
# Epoch   0 Batch  358/1077 - Train Accuracy: 0.5374, Validation Accuracy: 0.5874, Loss: 0.8488
# Epoch   0 Batch  359/1077 - Train Accuracy: 0.5715, Validation Accuracy: 0.5799, Loss: 0.8260
# Epoch   0 Batch  360/1077 - Train Accuracy: 0.5668, Validation Accuracy: 0.5803, Loss: 0.8001
# Epoch   0 Batch  361/1077 - Train Accuracy: 0.5958, Validation Accuracy: 0.5881, Loss: 0.8339
# Epoch   0 Batch  362/1077 - Train Accuracy: 0.6019, Validation Accuracy: 0.5863, Loss: 0.8164
# Epoch   0 Batch  363/1077 - Train Accuracy: 0.5414, Validation Accuracy: 0.5763, Loss: 0.8377
# Epoch   0 Batch  364/1077 - Train Accuracy: 0.5801, Validation Accuracy: 0.5987, Loss: 0.8359
# Epoch   0 Batch  365/1077 - Train Accuracy: 0.5457, Validation Accuracy: 0.6016, Loss: 0.7881
# Epoch   0 Batch  366/1077 - Train Accuracy: 0.5598, Validation Accuracy: 0.5859, Loss: 0.8208
# Epoch   0 Batch  367/1077 - Train Accuracy: 0.5800, Validation Accuracy: 0.5806, Loss: 0.7234
# Epoch   0 Batch  368/1077 - Train Accuracy: 0.6098, Validation Accuracy: 0.5927, Loss: 0.7963
# Epoch   0 Batch  369/1077 - Train Accuracy: 0.5527, Validation Accuracy: 0.5934, Loss: 0.7993
# Epoch   0 Batch  370/1077 - Train Accuracy: 0.6150, Validation Accuracy: 0.5920, Loss: 0.7474
# Epoch   0 Batch  371/1077 - Train Accuracy: 0.6000, Validation Accuracy: 0.5994, Loss: 0.7720
# Epoch   0 Batch  372/1077 - Train Accuracy: 0.5695, Validation Accuracy: 0.5923, Loss: 0.8078
# Epoch   0 Batch  373/1077 - Train Accuracy: 0.6250, Validation Accuracy: 0.5969, Loss: 0.7287
# Epoch   0 Batch  374/1077 - Train Accuracy: 0.5516, Validation Accuracy: 0.5945, Loss: 0.8359
# Epoch   0 Batch  375/1077 - Train Accuracy: 0.6009, Validation Accuracy: 0.5884, Loss: 0.7397
# Epoch   0 Batch  376/1077 - Train Accuracy: 0.6143, Validation Accuracy: 0.5962, Loss: 0.7411
# Epoch   0 Batch  377/1077 - Train Accuracy: 0.5898, Validation Accuracy: 0.5955, Loss: 0.7835
# Epoch   0 Batch  378/1077 - Train Accuracy: 0.5770, Validation Accuracy: 0.5934, Loss: 0.7498
# Epoch   0 Batch  379/1077 - Train Accuracy: 0.6078, Validation Accuracy: 0.6076, Loss: 0.7958
# Epoch   0 Batch  380/1077 - Train Accuracy: 0.5789, Validation Accuracy: 0.5902, Loss: 0.7663
# Epoch   0 Batch  381/1077 - Train Accuracy: 0.5820, Validation Accuracy: 0.5827, Loss: 0.8053
# Epoch   0 Batch  382/1077 - Train Accuracy: 0.5934, Validation Accuracy: 0.5813, Loss: 0.8020
# Epoch   0 Batch  383/1077 - Train Accuracy: 0.5904, Validation Accuracy: 0.5788, Loss: 0.7478
# Epoch   0 Batch  384/1077 - Train Accuracy: 0.5867, Validation Accuracy: 0.5938, Loss: 0.7651
# Epoch   0 Batch  385/1077 - Train Accuracy: 0.5695, Validation Accuracy: 0.6026, Loss: 0.8067
# Epoch   0 Batch  386/1077 - Train Accuracy: 0.5737, Validation Accuracy: 0.6037, Loss: 0.7587
# Epoch   0 Batch  387/1077 - Train Accuracy: 0.6207, Validation Accuracy: 0.6087, Loss: 0.7714
# Epoch   0 Batch  388/1077 - Train Accuracy: 0.5964, Validation Accuracy: 0.6072, Loss: 0.7543
# Epoch   0 Batch  389/1077 - Train Accuracy: 0.6020, Validation Accuracy: 0.6001, Loss: 0.7660
# Epoch   0 Batch  390/1077 - Train Accuracy: 0.5672, Validation Accuracy: 0.6012, Loss: 0.7979
# Epoch   0 Batch  391/1077 - Train Accuracy: 0.6038, Validation Accuracy: 0.5973, Loss: 0.7401
# Epoch   0 Batch  392/1077 - Train Accuracy: 0.5754, Validation Accuracy: 0.5984, Loss: 0.7587
# Epoch   0 Batch  393/1077 - Train Accuracy: 0.5997, Validation Accuracy: 0.5948, Loss: 0.7293
# Epoch   0 Batch  394/1077 - Train Accuracy: 0.5496, Validation Accuracy: 0.5863, Loss: 0.7744
# Epoch   0 Batch  395/1077 - Train Accuracy: 0.5800, Validation Accuracy: 0.5948, Loss: 0.7289
# Epoch   0 Batch  396/1077 - Train Accuracy: 0.5719, Validation Accuracy: 0.5966, Loss: 0.7672
# Epoch   0 Batch  397/1077 - Train Accuracy: 0.6053, Validation Accuracy: 0.6094, Loss: 0.7484
# Epoch   0 Batch  398/1077 - Train Accuracy: 0.5715, Validation Accuracy: 0.5998, Loss: 0.8155
# Epoch   0 Batch  399/1077 - Train Accuracy: 0.5481, Validation Accuracy: 0.6069, Loss: 0.8225
# Epoch   0 Batch  400/1077 - Train Accuracy: 0.5980, Validation Accuracy: 0.5973, Loss: 0.7610
# Epoch   0 Batch  401/1077 - Train Accuracy: 0.5559, Validation Accuracy: 0.6026, Loss: 0.7688
# Epoch   0 Batch  402/1077 - Train Accuracy: 0.6375, Validation Accuracy: 0.5938, Loss: 0.6952
# Epoch   0 Batch  403/1077 - Train Accuracy: 0.5605, Validation Accuracy: 0.5888, Loss: 0.7901
# Epoch   0 Batch  404/1077 - Train Accuracy: 0.6187, Validation Accuracy: 0.6005, Loss: 0.7244
# Epoch   0 Batch  405/1077 - Train Accuracy: 0.5580, Validation Accuracy: 0.6012, Loss: 0.8223
# Epoch   0 Batch  406/1077 - Train Accuracy: 0.6090, Validation Accuracy: 0.6062, Loss: 0.7354
# Epoch   0 Batch  407/1077 - Train Accuracy: 0.5602, Validation Accuracy: 0.6069, Loss: 0.7919
# Epoch   0 Batch  408/1077 - Train Accuracy: 0.5785, Validation Accuracy: 0.6087, Loss: 0.7668
# Epoch   0 Batch  409/1077 - Train Accuracy: 0.5656, Validation Accuracy: 0.6051, Loss: 0.7766
# Epoch   0 Batch  410/1077 - Train Accuracy: 0.5436, Validation Accuracy: 0.6048, Loss: 0.8407
# Epoch   0 Batch  411/1077 - Train Accuracy: 0.6023, Validation Accuracy: 0.5930, Loss: 0.7990
# Epoch   0 Batch  412/1077 - Train Accuracy: 0.5910, Validation Accuracy: 0.5842, Loss: 0.7391
# Epoch   0 Batch  413/1077 - Train Accuracy: 0.5801, Validation Accuracy: 0.5973, Loss: 0.8097
# Epoch   0 Batch  414/1077 - Train Accuracy: 0.5687, Validation Accuracy: 0.6030, Loss: 0.7976
# Epoch   0 Batch  415/1077 - Train Accuracy: 0.5949, Validation Accuracy: 0.6175, Loss: 0.7021
# Epoch   0 Batch  416/1077 - Train Accuracy: 0.5750, Validation Accuracy: 0.6133, Loss: 0.7766
# Epoch   0 Batch  417/1077 - Train Accuracy: 0.5820, Validation Accuracy: 0.5994, Loss: 0.7880
# Epoch   0 Batch  418/1077 - Train Accuracy: 0.5648, Validation Accuracy: 0.5767, Loss: 0.7236
# Epoch   0 Batch  419/1077 - Train Accuracy: 0.5426, Validation Accuracy: 0.5835, Loss: 0.7655
# Epoch   0 Batch  420/1077 - Train Accuracy: 0.5895, Validation Accuracy: 0.5898, Loss: 0.7441
# Epoch   0 Batch  421/1077 - Train Accuracy: 0.5723, Validation Accuracy: 0.6172, Loss: 0.7771
# Epoch   0 Batch  422/1077 - Train Accuracy: 0.5844, Validation Accuracy: 0.6119, Loss: 0.7175
# Epoch   0 Batch  423/1077 - Train Accuracy: 0.6133, Validation Accuracy: 0.6158, Loss: 0.7801
# Epoch   0 Batch  424/1077 - Train Accuracy: 0.5563, Validation Accuracy: 0.6087, Loss: 0.7636
# Epoch   0 Batch  425/1077 - Train Accuracy: 0.6172, Validation Accuracy: 0.6026, Loss: 0.7116
# Epoch   0 Batch  426/1077 - Train Accuracy: 0.5762, Validation Accuracy: 0.5969, Loss: 0.7646
# Epoch   0 Batch  427/1077 - Train Accuracy: 0.5647, Validation Accuracy: 0.5994, Loss: 0.7461
# Epoch   0 Batch  428/1077 - Train Accuracy: 0.6023, Validation Accuracy: 0.5742, Loss: 0.7118
# Epoch   0 Batch  429/1077 - Train Accuracy: 0.5578, Validation Accuracy: 0.5703, Loss: 0.7127
# Epoch   0 Batch  430/1077 - Train Accuracy: 0.5578, Validation Accuracy: 0.5760, Loss: 0.7772
# Epoch   0 Batch  431/1077 - Train Accuracy: 0.5426, Validation Accuracy: 0.5746, Loss: 0.7461
# Epoch   0 Batch  432/1077 - Train Accuracy: 0.5867, Validation Accuracy: 0.5920, Loss: 0.7566
# Epoch   0 Batch  433/1077 - Train Accuracy: 0.5559, Validation Accuracy: 0.5898, Loss: 0.7438
# Epoch   0 Batch  434/1077 - Train Accuracy: 0.5656, Validation Accuracy: 0.5998, Loss: 0.7225
# Epoch   0 Batch  435/1077 - Train Accuracy: 0.5954, Validation Accuracy: 0.6019, Loss: 0.7673
# Epoch   0 Batch  436/1077 - Train Accuracy: 0.6105, Validation Accuracy: 0.6072, Loss: 0.7284
# Epoch   0 Batch  437/1077 - Train Accuracy: 0.5703, Validation Accuracy: 0.6218, Loss: 0.7289
# Epoch   0 Batch  438/1077 - Train Accuracy: 0.5809, Validation Accuracy: 0.6168, Loss: 0.7330
# Epoch   0 Batch  439/1077 - Train Accuracy: 0.5867, Validation Accuracy: 0.6204, Loss: 0.7398
# Epoch   0 Batch  440/1077 - Train Accuracy: 0.5914, Validation Accuracy: 0.6062, Loss: 0.7506
# Epoch   0 Batch  441/1077 - Train Accuracy: 0.5500, Validation Accuracy: 0.6104, Loss: 0.7257
# Epoch   0 Batch  442/1077 - Train Accuracy: 0.5822, Validation Accuracy: 0.5952, Loss: 0.6852
# Epoch   0 Batch  443/1077 - Train Accuracy: 0.5900, Validation Accuracy: 0.5998, Loss: 0.6745
# Epoch   0 Batch  444/1077 - Train Accuracy: 0.5789, Validation Accuracy: 0.5895, Loss: 0.7075
# Epoch   0 Batch  445/1077 - Train Accuracy: 0.5724, Validation Accuracy: 0.5973, Loss: 0.7610
# Epoch   0 Batch  446/1077 - Train Accuracy: 0.6079, Validation Accuracy: 0.5884, Loss: 0.6641
# Epoch   0 Batch  447/1077 - Train Accuracy: 0.5719, Validation Accuracy: 0.6009, Loss: 0.7080
# Epoch   0 Batch  448/1077 - Train Accuracy: 0.6105, Validation Accuracy: 0.5895, Loss: 0.7264
# Epoch   0 Batch  449/1077 - Train Accuracy: 0.5535, Validation Accuracy: 0.5817, Loss: 0.7494
# Epoch   0 Batch  450/1077 - Train Accuracy: 0.5707, Validation Accuracy: 0.5746, Loss: 0.6876
# Epoch   0 Batch  451/1077 - Train Accuracy: 0.5971, Validation Accuracy: 0.5803, Loss: 0.6842
# Epoch   0 Batch  452/1077 - Train Accuracy: 0.6020, Validation Accuracy: 0.6005, Loss: 0.7077
# Epoch   0 Batch  453/1077 - Train Accuracy: 0.6060, Validation Accuracy: 0.6065, Loss: 0.6618
# Epoch   0 Batch  454/1077 - Train Accuracy: 0.6012, Validation Accuracy: 0.6051, Loss: 0.7176
# Epoch   0 Batch  455/1077 - Train Accuracy: 0.6005, Validation Accuracy: 0.6005, Loss: 0.6598
# Epoch   0 Batch  456/1077 - Train Accuracy: 0.6023, Validation Accuracy: 0.6104, Loss: 0.7109
# Epoch   0 Batch  457/1077 - Train Accuracy: 0.5926, Validation Accuracy: 0.6101, Loss: 0.6484
# Epoch   0 Batch  458/1077 - Train Accuracy: 0.5598, Validation Accuracy: 0.6115, Loss: 0.7126
# Epoch   0 Batch  459/1077 - Train Accuracy: 0.6176, Validation Accuracy: 0.6168, Loss: 0.6671
# Epoch   0 Batch  460/1077 - Train Accuracy: 0.5707, Validation Accuracy: 0.6126, Loss: 0.6943
# Epoch   0 Batch  461/1077 - Train Accuracy: 0.6125, Validation Accuracy: 0.5977, Loss: 0.6885
# Epoch   0 Batch  462/1077 - Train Accuracy: 0.5938, Validation Accuracy: 0.5902, Loss: 0.6813
# Epoch   0 Batch  463/1077 - Train Accuracy: 0.5523, Validation Accuracy: 0.6072, Loss: 0.7223
# Epoch   0 Batch  464/1077 - Train Accuracy: 0.6230, Validation Accuracy: 0.6183, Loss: 0.6736
# Epoch   0 Batch  465/1077 - Train Accuracy: 0.6069, Validation Accuracy: 0.6101, Loss: 0.7363
# Epoch   0 Batch  466/1077 - Train Accuracy: 0.5977, Validation Accuracy: 0.6030, Loss: 0.6759
# Epoch   0 Batch  467/1077 - Train Accuracy: 0.6436, Validation Accuracy: 0.6026, Loss: 0.6529
# Epoch   0 Batch  468/1077 - Train Accuracy: 0.5967, Validation Accuracy: 0.6012, Loss: 0.6751
# Epoch   0 Batch  469/1077 - Train Accuracy: 0.5715, Validation Accuracy: 0.6016, Loss: 0.6984
# Epoch   0 Batch  470/1077 - Train Accuracy: 0.5600, Validation Accuracy: 0.6090, Loss: 0.7074
# Epoch   0 Batch  471/1077 - Train Accuracy: 0.6199, Validation Accuracy: 0.6040, Loss: 0.6702
# Epoch   0 Batch  472/1077 - Train Accuracy: 0.5871, Validation Accuracy: 0.6065, Loss: 0.6555
# Epoch   0 Batch  473/1077 - Train Accuracy: 0.5992, Validation Accuracy: 0.6072, Loss: 0.6877
# Epoch   0 Batch  474/1077 - Train Accuracy: 0.5902, Validation Accuracy: 0.6019, Loss: 0.6764
# Epoch   0 Batch  475/1077 - Train Accuracy: 0.6359, Validation Accuracy: 0.6097, Loss: 0.6565
# Epoch   0 Batch  476/1077 - Train Accuracy: 0.5781, Validation Accuracy: 0.6115, Loss: 0.6571
# Epoch   0 Batch  477/1077 - Train Accuracy: 0.6287, Validation Accuracy: 0.5923, Loss: 0.6342
# Epoch   0 Batch  478/1077 - Train Accuracy: 0.5826, Validation Accuracy: 0.5930, Loss: 0.6834
# Epoch   0 Batch  479/1077 - Train Accuracy: 0.5781, Validation Accuracy: 0.5991, Loss: 0.6881
# Epoch   0 Batch  480/1077 - Train Accuracy: 0.6040, Validation Accuracy: 0.6065, Loss: 0.6618
# Epoch   0 Batch  481/1077 - Train Accuracy: 0.5848, Validation Accuracy: 0.6136, Loss: 0.6529
# Epoch   0 Batch  482/1077 - Train Accuracy: 0.5925, Validation Accuracy: 0.6112, Loss: 0.7039
# Epoch   0 Batch  483/1077 - Train Accuracy: 0.5875, Validation Accuracy: 0.6165, Loss: 0.6593
# Epoch   0 Batch  484/1077 - Train Accuracy: 0.6027, Validation Accuracy: 0.6239, Loss: 0.6497
# Epoch   0 Batch  485/1077 - Train Accuracy: 0.6398, Validation Accuracy: 0.6232, Loss: 0.6603
# Epoch   0 Batch  486/1077 - Train Accuracy: 0.6266, Validation Accuracy: 0.6257, Loss: 0.6594
# Epoch   0 Batch  487/1077 - Train Accuracy: 0.5921, Validation Accuracy: 0.6179, Loss: 0.6842
# Epoch   0 Batch  488/1077 - Train Accuracy: 0.5979, Validation Accuracy: 0.6211, Loss: 0.6637
# Epoch   0 Batch  489/1077 - Train Accuracy: 0.6124, Validation Accuracy: 0.6154, Loss: 0.6234
# Epoch   0 Batch  490/1077 - Train Accuracy: 0.6012, Validation Accuracy: 0.6218, Loss: 0.6659
# Epoch   0 Batch  491/1077 - Train Accuracy: 0.6246, Validation Accuracy: 0.6282, Loss: 0.6447
# Epoch   0 Batch  492/1077 - Train Accuracy: 0.6297, Validation Accuracy: 0.6243, Loss: 0.6728
# Epoch   0 Batch  493/1077 - Train Accuracy: 0.6447, Validation Accuracy: 0.6197, Loss: 0.6049
# Epoch   0 Batch  494/1077 - Train Accuracy: 0.6133, Validation Accuracy: 0.6232, Loss: 0.6139
# Epoch   0 Batch  495/1077 - Train Accuracy: 0.5988, Validation Accuracy: 0.6317, Loss: 0.6454
# Epoch   0 Batch  496/1077 - Train Accuracy: 0.5891, Validation Accuracy: 0.6214, Loss: 0.6579
# Epoch   0 Batch  497/1077 - Train Accuracy: 0.5880, Validation Accuracy: 0.6257, Loss: 0.6882
# Epoch   0 Batch  498/1077 - Train Accuracy: 0.6312, Validation Accuracy: 0.6325, Loss: 0.6165
# Epoch   0 Batch  499/1077 - Train Accuracy: 0.6213, Validation Accuracy: 0.6293, Loss: 0.6024
# Epoch   0 Batch  500/1077 - Train Accuracy: 0.6113, Validation Accuracy: 0.6254, Loss: 0.6309
# Epoch   0 Batch  501/1077 - Train Accuracy: 0.6035, Validation Accuracy: 0.6289, Loss: 0.6121
# Epoch   0 Batch  502/1077 - Train Accuracy: 0.5996, Validation Accuracy: 0.6232, Loss: 0.6215
# Epoch   0 Batch  503/1077 - Train Accuracy: 0.6367, Validation Accuracy: 0.6271, Loss: 0.6355
# Epoch   0 Batch  504/1077 - Train Accuracy: 0.5914, Validation Accuracy: 0.6275, Loss: 0.6410
# Epoch   0 Batch  505/1077 - Train Accuracy: 0.6384, Validation Accuracy: 0.6342, Loss: 0.5689
# Epoch   0 Batch  506/1077 - Train Accuracy: 0.5934, Validation Accuracy: 0.6335, Loss: 0.6405
# Epoch   0 Batch  507/1077 - Train Accuracy: 0.6148, Validation Accuracy: 0.6293, Loss: 0.6169
# Epoch   0 Batch  508/1077 - Train Accuracy: 0.6317, Validation Accuracy: 0.6200, Loss: 0.6043
# Epoch   0 Batch  509/1077 - Train Accuracy: 0.5965, Validation Accuracy: 0.6151, Loss: 0.6483
# Epoch   0 Batch  510/1077 - Train Accuracy: 0.6078, Validation Accuracy: 0.6115, Loss: 0.6236
# ...
# Epoch   9 Batch  907/1077 - Train Accuracy: 0.9867, Validation Accuracy: 0.9837, Loss: 0.0054
# Epoch   9 Batch  908/1077 - Train Accuracy: 0.9824, Validation Accuracy: 0.9837, Loss: 0.0085
# Epoch   9 Batch  909/1077 - Train Accuracy: 0.9934, Validation Accuracy: 0.9815, Loss: 0.0078
# Epoch   9 Batch  910/1077 - Train Accuracy: 0.9903, Validation Accuracy: 0.9815, Loss: 0.0124
# Epoch   9 Batch  911/1077 - Train Accuracy: 0.9936, Validation Accuracy: 0.9815, Loss: 0.0073
# Epoch   9 Batch  912/1077 - Train Accuracy: 0.9941, Validation Accuracy: 0.9815, Loss: 0.0085
# Epoch   9 Batch  913/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9815, Loss: 0.0139
# Epoch   9 Batch  914/1077 - Train Accuracy: 0.9912, Validation Accuracy: 0.9819, Loss: 0.0117
# Epoch   9 Batch  915/1077 - Train Accuracy: 0.9988, Validation Accuracy: 0.9819, Loss: 0.0061
# Epoch   9 Batch  916/1077 - Train Accuracy: 0.9953, Validation Accuracy: 0.9819, Loss: 0.0058
# Epoch   9 Batch  917/1077 - Train Accuracy: 0.9863, Validation Accuracy: 0.9840, Loss: 0.0066
# Epoch   9 Batch  918/1077 - Train Accuracy: 0.9888, Validation Accuracy: 0.9840, Loss: 0.0077
# Epoch   9 Batch  919/1077 - Train Accuracy: 0.9942, Validation Accuracy: 0.9840, Loss: 0.0094
# Epoch   9 Batch  920/1077 - Train Accuracy: 1.0000, Validation Accuracy: 0.9840, Loss: 0.0032
# Epoch   9 Batch  921/1077 - Train Accuracy: 0.9879, Validation Accuracy: 0.9840, Loss: 0.0133
# Epoch   9 Batch  922/1077 - Train Accuracy: 0.9918, Validation Accuracy: 0.9840, Loss: 0.0084
# Epoch   9 Batch  923/1077 - Train Accuracy: 0.9938, Validation Accuracy: 0.9844, Loss: 0.0100
# Epoch   9 Batch  924/1077 - Train Accuracy: 0.9860, Validation Accuracy: 0.9844, Loss: 0.0158
# Epoch   9 Batch  925/1077 - Train Accuracy: 0.9918, Validation Accuracy: 0.9822, Loss: 0.0072
# Epoch   9 Batch  926/1077 - Train Accuracy: 0.9855, Validation Accuracy: 0.9822, Loss: 0.0079
# Epoch   9 Batch  927/1077 - Train Accuracy: 0.9875, Validation Accuracy: 0.9822, Loss: 0.0111
# Epoch   9 Batch  928/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9822, Loss: 0.0115
# Epoch   9 Batch  929/1077 - Train Accuracy: 0.9941, Validation Accuracy: 0.9822, Loss: 0.0065
# Epoch   9 Batch  930/1077 - Train Accuracy: 0.9965, Validation Accuracy: 0.9822, Loss: 0.0054
# Epoch   9 Batch  931/1077 - Train Accuracy: 0.9934, Validation Accuracy: 0.9822, Loss: 0.0109
# Epoch   9 Batch  932/1077 - Train Accuracy: 0.9875, Validation Accuracy: 0.9822, Loss: 0.0079
# Epoch   9 Batch  933/1077 - Train Accuracy: 0.9820, Validation Accuracy: 0.9822, Loss: 0.0075
# Epoch   9 Batch  934/1077 - Train Accuracy: 0.9855, Validation Accuracy: 0.9822, Loss: 0.0101
# Epoch   9 Batch  935/1077 - Train Accuracy: 0.9898, Validation Accuracy: 0.9773, Loss: 0.0070
# Epoch   9 Batch  936/1077 - Train Accuracy: 0.9937, Validation Accuracy: 0.9773, Loss: 0.0093
# Epoch   9 Batch  937/1077 - Train Accuracy: 0.9967, Validation Accuracy: 0.9798, Loss: 0.0079
# Epoch   9 Batch  938/1077 - Train Accuracy: 0.9965, Validation Accuracy: 0.9794, Loss: 0.0067
# Epoch   9 Batch  939/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9794, Loss: 0.0128
# Epoch   9 Batch  940/1077 - Train Accuracy: 0.9938, Validation Accuracy: 0.9794, Loss: 0.0128
# Epoch   9 Batch  941/1077 - Train Accuracy: 0.9862, Validation Accuracy: 0.9794, Loss: 0.0066
# Epoch   9 Batch  942/1077 - Train Accuracy: 0.9871, Validation Accuracy: 0.9794, Loss: 0.0106
# Epoch   9 Batch  943/1077 - Train Accuracy: 0.9961, Validation Accuracy: 0.9744, Loss: 0.0096
# Epoch   9 Batch  944/1077 - Train Accuracy: 0.9900, Validation Accuracy: 0.9794, Loss: 0.0062
# Epoch   9 Batch  945/1077 - Train Accuracy: 0.9938, Validation Accuracy: 0.9794, Loss: 0.0067
# Epoch   9 Batch  946/1077 - Train Accuracy: 0.9992, Validation Accuracy: 0.9794, Loss: 0.0043
# Epoch   9 Batch  947/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9794, Loss: 0.0092
# Epoch   9 Batch  948/1077 - Train Accuracy: 0.9973, Validation Accuracy: 0.9794, Loss: 0.0098
# Epoch   9 Batch  949/1077 - Train Accuracy: 0.9799, Validation Accuracy: 0.9794, Loss: 0.0156
# Epoch   9 Batch  950/1077 - Train Accuracy: 0.9989, Validation Accuracy: 0.9794, Loss: 0.0053
# Epoch   9 Batch  951/1077 - Train Accuracy: 0.9706, Validation Accuracy: 0.9794, Loss: 0.0153
# Epoch   9 Batch  952/1077 - Train Accuracy: 0.9996, Validation Accuracy: 0.9741, Loss: 0.0040
# Epoch   9 Batch  953/1077 - Train Accuracy: 0.9819, Validation Accuracy: 0.9741, Loss: 0.0101
# Epoch   9 Batch  954/1077 - Train Accuracy: 0.9977, Validation Accuracy: 0.9737, Loss: 0.0062
# Epoch   9 Batch  955/1077 - Train Accuracy: 0.9934, Validation Accuracy: 0.9737, Loss: 0.0105
# Epoch   9 Batch  956/1077 - Train Accuracy: 0.9805, Validation Accuracy: 0.9737, Loss: 0.0151
# Epoch   9 Batch  957/1077 - Train Accuracy: 1.0000, Validation Accuracy: 0.9737, Loss: 0.0084
# Epoch   9 Batch  958/1077 - Train Accuracy: 0.9855, Validation Accuracy: 0.9787, Loss: 0.0075
# Epoch   9 Batch  959/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9801, Loss: 0.0114
# Epoch   9 Batch  960/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9805, Loss: 0.0083
# Epoch   9 Batch  961/1077 - Train Accuracy: 0.9891, Validation Accuracy: 0.9805, Loss: 0.0059
# Epoch   9 Batch  962/1077 - Train Accuracy: 0.9974, Validation Accuracy: 0.9755, Loss: 0.0096
# Epoch   9 Batch  963/1077 - Train Accuracy: 0.9878, Validation Accuracy: 0.9783, Loss: 0.0123
# Epoch   9 Batch  964/1077 - Train Accuracy: 0.9833, Validation Accuracy: 0.9737, Loss: 0.0130
# Epoch   9 Batch  965/1077 - Train Accuracy: 0.9873, Validation Accuracy: 0.9737, Loss: 0.0101
# Epoch   9 Batch  966/1077 - Train Accuracy: 0.9901, Validation Accuracy: 0.9737, Loss: 0.0075
# Epoch   9 Batch  967/1077 - Train Accuracy: 0.9938, Validation Accuracy: 0.9737, Loss: 0.0082
# Epoch   9 Batch  968/1077 - Train Accuracy: 0.9945, Validation Accuracy: 0.9737, Loss: 0.0076
# Epoch   9 Batch  969/1077 - Train Accuracy: 0.9844, Validation Accuracy: 0.9737, Loss: 0.0121
# Epoch   9 Batch  970/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9737, Loss: 0.0153
# Epoch   9 Batch  971/1077 - Train Accuracy: 0.9937, Validation Accuracy: 0.9734, Loss: 0.0080
# Epoch   9 Batch  972/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9783, Loss: 0.0052
# Epoch   9 Batch  973/1077 - Train Accuracy: 0.9955, Validation Accuracy: 0.9783, Loss: 0.0056
# Epoch   9 Batch  974/1077 - Train Accuracy: 0.9801, Validation Accuracy: 0.9759, Loss: 0.0080
# Epoch   9 Batch  975/1077 - Train Accuracy: 0.9922, Validation Accuracy: 0.9759, Loss: 0.0089
# Epoch   9 Batch  976/1077 - Train Accuracy: 0.9801, Validation Accuracy: 0.9808, Loss: 0.0088
# Epoch   9 Batch  977/1077 - Train Accuracy: 0.9906, Validation Accuracy: 0.9808, Loss: 0.0059
# Epoch   9 Batch  978/1077 - Train Accuracy: 0.9957, Validation Accuracy: 0.9755, Loss: 0.0085
# Epoch   9 Batch  979/1077 - Train Accuracy: 0.9807, Validation Accuracy: 0.9755, Loss: 0.0098
# Epoch   9 Batch  980/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9755, Loss: 0.0079
# Epoch   9 Batch  981/1077 - Train Accuracy: 0.9871, Validation Accuracy: 0.9755, Loss: 0.0077
# Epoch   9 Batch  982/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9755, Loss: 0.0070
# Epoch   9 Batch  983/1077 - Train Accuracy: 0.9885, Validation Accuracy: 0.9755, Loss: 0.0065
# Epoch   9 Batch  984/1077 - Train Accuracy: 0.9738, Validation Accuracy: 0.9755, Loss: 0.0106
# Epoch   9 Batch  985/1077 - Train Accuracy: 0.9996, Validation Accuracy: 0.9805, Loss: 0.0077
# Epoch   9 Batch  986/1077 - Train Accuracy: 0.9875, Validation Accuracy: 0.9790, Loss: 0.0107
# Epoch   9 Batch  987/1077 - Train Accuracy: 0.9821, Validation Accuracy: 0.9794, Loss: 0.0099
# Epoch   9 Batch  988/1077 - Train Accuracy: 0.9871, Validation Accuracy: 0.9730, Loss: 0.0133
# Epoch   9 Batch  989/1077 - Train Accuracy: 0.9891, Validation Accuracy: 0.9730, Loss: 0.0087
# Epoch   9 Batch  990/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9794, Loss: 0.0078
# Epoch   9 Batch  991/1077 - Train Accuracy: 0.9953, Validation Accuracy: 0.9794, Loss: 0.0070
# Epoch   9 Batch  992/1077 - Train Accuracy: 0.9887, Validation Accuracy: 0.9794, Loss: 0.0063
# Epoch   9 Batch  993/1077 - Train Accuracy: 0.9871, Validation Accuracy: 0.9794, Loss: 0.0062
# Epoch   9 Batch  994/1077 - Train Accuracy: 0.9820, Validation Accuracy: 0.9830, Loss: 0.0116
# Epoch   9 Batch  995/1077 - Train Accuracy: 0.9989, Validation Accuracy: 0.9830, Loss: 0.0063
# Epoch   9 Batch  996/1077 - Train Accuracy: 0.9906, Validation Accuracy: 0.9830, Loss: 0.0040
# Epoch   9 Batch  997/1077 - Train Accuracy: 0.9955, Validation Accuracy: 0.9812, Loss: 0.0053
# Epoch   9 Batch  998/1077 - Train Accuracy: 0.9844, Validation Accuracy: 0.9812, Loss: 0.0071
# Epoch   9 Batch  999/1077 - Train Accuracy: 0.9875, Validation Accuracy: 0.9762, Loss: 0.0140
# Epoch   9 Batch 1000/1077 - Train Accuracy: 0.9888, Validation Accuracy: 0.9698, Loss: 0.0065
# Epoch   9 Batch 1001/1077 - Train Accuracy: 0.9929, Validation Accuracy: 0.9648, Loss: 0.0107
# Epoch   9 Batch 1002/1077 - Train Accuracy: 0.9984, Validation Accuracy: 0.9599, Loss: 0.0053
# Epoch   9 Batch 1003/1077 - Train Accuracy: 0.9877, Validation Accuracy: 0.9574, Loss: 0.0115
# Epoch   9 Batch 1004/1077 - Train Accuracy: 0.9934, Validation Accuracy: 0.9574, Loss: 0.0082
# Epoch   9 Batch 1005/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9574, Loss: 0.0107
# Epoch   9 Batch 1006/1077 - Train Accuracy: 0.9941, Validation Accuracy: 0.9574, Loss: 0.0083
# Epoch   9 Batch 1007/1077 - Train Accuracy: 0.9918, Validation Accuracy: 0.9624, Loss: 0.0086
# Epoch   9 Batch 1008/1077 - Train Accuracy: 0.9918, Validation Accuracy: 0.9648, Loss: 0.0112
# Epoch   9 Batch 1009/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9648, Loss: 0.0025
# Epoch   9 Batch 1010/1077 - Train Accuracy: 0.9918, Validation Accuracy: 0.9648, Loss: 0.0069
# Epoch   9 Batch 1011/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9648, Loss: 0.0051
# Epoch   9 Batch 1012/1077 - Train Accuracy: 0.9807, Validation Accuracy: 0.9645, Loss: 0.0096
# Epoch   9 Batch 1013/1077 - Train Accuracy: 0.9974, Validation Accuracy: 0.9595, Loss: 0.0066
# Epoch   9 Batch 1014/1077 - Train Accuracy: 0.9863, Validation Accuracy: 0.9595, Loss: 0.0048
# Epoch   9 Batch 1015/1077 - Train Accuracy: 0.9875, Validation Accuracy: 0.9627, Loss: 0.0072
# Epoch   9 Batch 1016/1077 - Train Accuracy: 0.9877, Validation Accuracy: 0.9627, Loss: 0.0085
# Epoch   9 Batch 1017/1077 - Train Accuracy: 0.9877, Validation Accuracy: 0.9666, Loss: 0.0125
# Epoch   9 Batch 1018/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9691, Loss: 0.0101
# Epoch   9 Batch 1019/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9741, Loss: 0.0142
# Epoch   9 Batch 1020/1077 - Train Accuracy: 0.9938, Validation Accuracy: 0.9737, Loss: 0.0071
# Epoch   9 Batch 1021/1077 - Train Accuracy: 0.9851, Validation Accuracy: 0.9762, Loss: 0.0058
# Epoch   9 Batch 1022/1077 - Train Accuracy: 0.9885, Validation Accuracy: 0.9762, Loss: 0.0085
# Epoch   9 Batch 1023/1077 - Train Accuracy: 0.9879, Validation Accuracy: 0.9762, Loss: 0.0089
# Epoch   9 Batch 1024/1077 - Train Accuracy: 0.9883, Validation Accuracy: 0.9762, Loss: 0.0119
# Epoch   9 Batch 1025/1077 - Train Accuracy: 0.9866, Validation Accuracy: 0.9762, Loss: 0.0074
# Epoch   9 Batch 1026/1077 - Train Accuracy: 0.9978, Validation Accuracy: 0.9812, Loss: 0.0061
# Epoch   9 Batch 1027/1077 - Train Accuracy: 0.9891, Validation Accuracy: 0.9815, Loss: 0.0093
# Epoch   9 Batch 1028/1077 - Train Accuracy: 0.9911, Validation Accuracy: 0.9812, Loss: 0.0079
# Epoch   9 Batch 1029/1077 - Train Accuracy: 0.9934, Validation Accuracy: 0.9812, Loss: 0.0047
# Epoch   9 Batch 1030/1077 - Train Accuracy: 0.9922, Validation Accuracy: 0.9812, Loss: 0.0062
# Epoch   9 Batch 1031/1077 - Train Accuracy: 0.9877, Validation Accuracy: 0.9812, Loss: 0.0087
# Epoch   9 Batch 1032/1077 - Train Accuracy: 0.9829, Validation Accuracy: 0.9830, Loss: 0.0106
# Epoch   9 Batch 1033/1077 - Train Accuracy: 0.9944, Validation Accuracy: 0.9776, Loss: 0.0082
# Epoch   9 Batch 1034/1077 - Train Accuracy: 0.9898, Validation Accuracy: 0.9780, Loss: 0.0106
# Epoch   9 Batch 1035/1077 - Train Accuracy: 0.9944, Validation Accuracy: 0.9780, Loss: 0.0041
# Epoch   9 Batch 1036/1077 - Train Accuracy: 0.9874, Validation Accuracy: 0.9822, Loss: 0.0074
# Epoch   9 Batch 1037/1077 - Train Accuracy: 0.9906, Validation Accuracy: 0.9822, Loss: 0.0111
# Epoch   9 Batch 1038/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9822, Loss: 0.0077
# Epoch   9 Batch 1039/1077 - Train Accuracy: 0.9874, Validation Accuracy: 0.9822, Loss: 0.0099
# Epoch   9 Batch 1040/1077 - Train Accuracy: 0.9844, Validation Accuracy: 0.9822, Loss: 0.0095
# Epoch   9 Batch 1041/1077 - Train Accuracy: 0.9871, Validation Accuracy: 0.9819, Loss: 0.0106
# Epoch   9 Batch 1042/1077 - Train Accuracy: 0.9941, Validation Accuracy: 0.9869, Loss: 0.0060
# Epoch   9 Batch 1043/1077 - Train Accuracy: 0.9969, Validation Accuracy: 0.9869, Loss: 0.0094
# Epoch   9 Batch 1044/1077 - Train Accuracy: 0.9965, Validation Accuracy: 0.9869, Loss: 0.0073
# Epoch   9 Batch 1045/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9869, Loss: 0.0086
# Epoch   9 Batch 1046/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9883, Loss: 0.0042
# Epoch   9 Batch 1047/1077 - Train Accuracy: 0.9988, Validation Accuracy: 0.9883, Loss: 0.0047
# Epoch   9 Batch 1048/1077 - Train Accuracy: 0.9891, Validation Accuracy: 0.9833, Loss: 0.0086
# Epoch   9 Batch 1049/1077 - Train Accuracy: 0.9930, Validation Accuracy: 0.9833, Loss: 0.0055
# Epoch   9 Batch 1050/1077 - Train Accuracy: 0.9957, Validation Accuracy: 0.9808, Loss: 0.0050
# Epoch   9 Batch 1051/1077 - Train Accuracy: 0.9844, Validation Accuracy: 0.9808, Loss: 0.0176
# Epoch   9 Batch 1052/1077 - Train Accuracy: 0.9989, Validation Accuracy: 0.9805, Loss: 0.0039
# Epoch   9 Batch 1053/1077 - Train Accuracy: 0.9877, Validation Accuracy: 0.9805, Loss: 0.0111
# Epoch   9 Batch 1054/1077 - Train Accuracy: 0.9730, Validation Accuracy: 0.9808, Loss: 0.0080
# Epoch   9 Batch 1055/1077 - Train Accuracy: 0.9832, Validation Accuracy: 0.9808, Loss: 0.0094
# Epoch   9 Batch 1056/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9808, Loss: 0.0079
# Epoch   9 Batch 1057/1077 - Train Accuracy: 1.0000, Validation Accuracy: 0.9805, Loss: 0.0081
# Epoch   9 Batch 1058/1077 - Train Accuracy: 0.9786, Validation Accuracy: 0.9801, Loss: 0.0135
# Epoch   9 Batch 1059/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9826, Loss: 0.0123
# Epoch   9 Batch 1060/1077 - Train Accuracy: 0.9898, Validation Accuracy: 0.9826, Loss: 0.0078
# Epoch   9 Batch 1061/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9830, Loss: 0.0102
# Epoch   9 Batch 1062/1077 - Train Accuracy: 0.9996, Validation Accuracy: 0.9883, Loss: 0.0035
# Epoch   9 Batch 1063/1077 - Train Accuracy: 0.9930, Validation Accuracy: 0.9883, Loss: 0.0105
# Epoch   9 Batch 1064/1077 - Train Accuracy: 0.9941, Validation Accuracy: 0.9883, Loss: 0.0084
# Epoch   9 Batch 1065/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9883, Loss: 0.0088
# Epoch   9 Batch 1066/1077 - Train Accuracy: 0.9914, Validation Accuracy: 0.9883, Loss: 0.0166
# Epoch   9 Batch 1067/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9858, Loss: 0.0111
# Epoch   9 Batch 1068/1077 - Train Accuracy: 0.9887, Validation Accuracy: 0.9858, Loss: 0.0079
# Epoch   9 Batch 1069/1077 - Train Accuracy: 0.9937, Validation Accuracy: 0.9854, Loss: 0.0080
# Epoch   9 Batch 1070/1077 - Train Accuracy: 0.9973, Validation Accuracy: 0.9854, Loss: 0.0045
# Epoch   9 Batch 1071/1077 - Train Accuracy: 0.9879, Validation Accuracy: 0.9854, Loss: 0.0107
# Epoch   9 Batch 1072/1077 - Train Accuracy: 0.9933, Validation Accuracy: 0.9858, Loss: 0.0055
# Epoch   9 Batch 1073/1077 - Train Accuracy: 0.9895, Validation Accuracy: 0.9858, Loss: 0.0078
# Epoch   9 Batch 1074/1077 - Train Accuracy: 0.9926, Validation Accuracy: 0.9858, Loss: 0.0088
# Epoch   9 Batch 1075/1077 - Train Accuracy: 0.9782, Validation Accuracy: 0.9858, Loss: 0.0134
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    words = sentence.lower().split()
    word_id_list = [vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in words]
    return word_id_list


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [225, 34, 179, 195, 163, 90, 13]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [108, 9, 130, 298, 61, 175, 276, 1]
#   French Words: il vu un vieux camion jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
